# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score
from sklearn.utils.class_weight import compute_class_weight

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
df = pd.read_csv('Churn_Modelling.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.drop(columns=['RowNumber', 'CustomerId', 'Surname'], inplace=True)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df = pd.get_dummies(df, columns=['Geography', 'Gender'], drop_first=True, dtype=int)

# %%
# Split features and target
x = df.drop(columns=['Exited'])
y = df['Exited']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
s = StandardScaler()
X_train_scaled = s.fit_transform(X_train)
X_test_scaled = s.transform(X_test)

# %%
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = {0: class_weights[0], 1: class_weights[1]}

# %%
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='sigmoid')
])
# Out:
# c:\Anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
optimizer = Adam(learning_rate=0.0008)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
hist = model.fit(X_train_scaled, y_train, 
                 epochs=150, 
                 validation_split=0.2, 
                 class_weight=class_weight_dict,
                 callbacks=[early_stop],
                 batch_size=64)
# Out:
# Epoch 1/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6352 - loss: 0.6555 - val_accuracy: 0.6894 - val_loss: 0.5995
# Epoch 2/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6756 - loss: 0.5982 - val_accuracy: 0.7038 - val_loss: 0.5606
# Epoch 3/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6969 - loss: 0.5797 - val_accuracy: 0.7163 - val_loss: 0.5473
# Epoch 4/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7059 - loss: 0.5642 - val_accuracy: 0.7300 - val_loss: 0.5357
# Epoch 5/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7208 - loss: 0.5449 - val_accuracy: 0.7556 - val_loss: 0.5108
# Epoch 6/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7303 - loss: 0.5360 - val_accuracy: 0.7531 - val_loss: 0.5090
# Epoch 7/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7441 - loss: 0.5215 - val_accuracy: 0.7638 - val_loss: 0.4923
# Epoch 8/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7528 - loss: 0.5134 - val_accuracy: 0.7650 - val_loss: 0.4877
# Epoch 9/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7581 - loss: 0.5091 - val_accuracy: 0.7675 - val_loss: 0.4842
# Epoch 10/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7614 - loss: 0.4988 - val_accuracy: 0.7819 - val_loss: 0.4702
# Epoch 11/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7639 - loss: 0.5015 - val_accuracy: 0.7812 - val_loss: 0.4729
# Epoch 12/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7758 - loss: 0.4936 - val_accuracy: 0.7819 - val_loss: 0.4643
# Epoch 13/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7731 - loss: 0.4926 - val_accuracy: 0.7806 - val_loss: 0.4640
# Epoch 14/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7783 - loss: 0.4852 - val_accuracy: 0.7775 - val_loss: 0.4645
# Epoch 15/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7786 - loss: 0.4880 - val_accuracy: 0.7812 - val_loss: 0.4607
# Epoch 16/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7731 - loss: 0.4839 - val_accuracy: 0.7850 - val_loss: 0.4585
# Epoch 17/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7745 - loss: 0.4813 - val_accuracy: 0.7869 - val_loss: 0.4519
# Epoch 18/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7775 - loss: 0.4777 - val_accuracy: 0.7931 - val_loss: 0.4478
# Epoch 19/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7887 - loss: 0.4774 - val_accuracy: 0.7887 - val_loss: 0.4536
# Epoch 20/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7823 - loss: 0.4725 - val_accuracy: 0.7937 - val_loss: 0.4505
# Epoch 21/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7875 - loss: 0.4743 - val_accuracy: 0.7969 - val_loss: 0.4476
# Epoch 22/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7831 - loss: 0.4719 - val_accuracy: 0.7925 - val_loss: 0.4487
# Epoch 23/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7837 - loss: 0.4738 - val_accuracy: 0.7937 - val_loss: 0.4517
# Epoch 24/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7906 - loss: 0.4737 - val_accuracy: 0.7906 - val_loss: 0.4527
# Epoch 25/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7928 - loss: 0.4654 - val_accuracy: 0.7937 - val_loss: 0.4465
# Epoch 26/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7866 - loss: 0.4730 - val_accuracy: 0.7925 - val_loss: 0.4480
# Epoch 27/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7925 - loss: 0.4655 - val_accuracy: 0.7937 - val_loss: 0.4447
# Epoch 28/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7902 - loss: 0.4699 - val_accuracy: 0.7925 - val_loss: 0.4522
# Epoch 29/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7936 - loss: 0.4698 - val_accuracy: 0.7944 - val_loss: 0.4406
# Epoch 30/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7984 - loss: 0.4621 - val_accuracy: 0.7987 - val_loss: 0.4431
# Epoch 31/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7922 - loss: 0.4643 - val_accuracy: 0.8000 - val_loss: 0.4411
# Epoch 32/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7995 - loss: 0.4601 - val_accuracy: 0.7956 - val_loss: 0.4448
# Epoch 33/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7920 - loss: 0.4628 - val_accuracy: 0.7956 - val_loss: 0.4384
# Epoch 34/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7972 - loss: 0.4645 - val_accuracy: 0.7962 - val_loss: 0.4370
# Epoch 35/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7972 - loss: 0.4572 - val_accuracy: 0.7894 - val_loss: 0.4441
# Epoch 36/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8008 - loss: 0.4577 - val_accuracy: 0.7931 - val_loss: 0.4402
# Epoch 37/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8016 - loss: 0.4568 - val_accuracy: 0.7937 - val_loss: 0.4389
# Epoch 38/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7953 - loss: 0.4562 - val_accuracy: 0.7900 - val_loss: 0.4419
# Epoch 39/150
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7995 - loss: 0.4576 - val_accuracy: 0.7937 - val_loss: 0.4442

# %%
# 7. Evaluation
# Get raw probabilities
y_probs = model.predict(X_test_scaled)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
best_thresh = 0.5
best_f1 = 0
for thresh in np.arange(0.3, 0.7, 0.01):
    y_pred_temp = (y_probs > thresh).astype(int)
    f1_temp = f1_score(y_test, y_pred_temp)
    if f1_temp > best_f1:
        best_f1 = f1_temp
        best_thresh = thresh

# %%
y_pred = np.where(y_probs > best_thresh, 1, 0)

# %%
ann_accuracy = accuracy_score(y_test, y_pred)
ann_auc = roc_auc_score(y_test, y_probs)
ann_f1 = f1_score(y_test, y_pred)

# %%
print(f"\n--- ANN Results (Threshold: {best_thresh:.2f}) ---")
print(f"Accuracy:  {ann_accuracy:.4f}")
print(f"AUC-ROC:   {ann_auc:.4f}")
print(f"F1-Score:  {ann_f1:.4f}")
# Out:
# --- ANN Results (Threshold: 0.67) ---
# Accuracy:  0.8555
# AUC-ROC:   0.8555
# F1-Score:  0.6131

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(hist.history['loss'], label='Train Loss')
plt.plot(hist.history['val_loss'], label='Val Loss')
plt.title('Loss Curve')
plt.legend()

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(hist.history['accuracy'], label='Train Acc')
plt.plot(hist.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy Curve')
plt.legend()
